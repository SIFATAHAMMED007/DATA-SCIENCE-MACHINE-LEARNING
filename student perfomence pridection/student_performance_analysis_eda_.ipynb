# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
content = "/content/exams.csv"
df = pd.read_csv(content)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df["gender"].value_counts()
# Out:
# gender
# male      517
# female    483
# Name: count, dtype: int64

# %%
df["parental level of education"].value_counts()
# Out:
# parental level of education
# some college          222
# associate's degree    203
# high school           202
# some high school      191
# bachelor's degree     112
# master's degree        70
# Name: count, dtype: int64

# %%
df["race/ethnicity"].value_counts()
# Out:
# race/ethnicity
# group C    323
# group D    262
# group B    205
# group E    131
# group A     79
# Name: count, dtype: int64

# %%
df["lunch"].value_counts()
# Out:
# lunch
# standard        652
# free/reduced    348
# Name: count, dtype: int64

# %%
df["test preparation course"].value_counts()
# Out:
# test preparation course
# none         665
# completed    335
# Name: count, dtype: int64

# %%
df["total"] = df["math score"] + df["reading score"] + df["writing score"]

# %%
df["average"] = round(df["total"] / 3,2)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0               completed          67             67             63    197
# 1                    none          40             59             55    154
# 2                    none          59             60             50    169
# 3                    none          77             78             68    223
# 4               completed          78             73             68    219
#
#    average
# 0    65.67
# 1    51.33
# 2    56.33
# 3    74.33
# 4    73.00

# %%
sns.distplot(df["math score"])
# Out:
# <ipython-input-29-7cee1a95ae00>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["math score"])
# <Axes: xlabel='math score', ylabel='Density'>

# %%
sns.distplot(df["reading score"])
# Out:
# <ipython-input-30-1795946deca9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["reading score"])
# <Axes: xlabel='reading score', ylabel='Density'>

# %%
sns.distplot(df["writing score"])
# Out:
# <ipython-input-31-ee9317e32d74>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["writing score"])
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
sns.distplot(df["average"])
# Out:
# <ipython-input-32-f1246c6c3432>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["average"])
# <Axes: xlabel='average', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.barplot(x="race/ethnicity", y="average", data=df)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='average'>

# %%
sns.barplot(x="average", y="parental level of education", data=df)
plt.figure(figsize=(15, 10))

# %%
sns.barplot(x="test preparation course", y="average", data=df)
# Out:
# <Axes: xlabel='test preparation course', ylabel='average'>

# %%
df["math_pass"] = np.where(df["math score"] < 40,"F","P")
df["read_pass"] = np.where(df["reading score"] < 40,"F","P")
df["write_pass"] = np.where(df["writing score"] < 40,"F","P")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0               completed          67             67             63    197
# 1                    none          40             59             55    154
# 2                    none          59             60             50    169
# 3                    none          77             78             68    223
# 4               completed          78             73             68    219
#
#    average math_pass reading_pass write_pass read_pass
# 0    65.67         P            P          P         P
# ...

# %%
df["math_pass"].value_counts()
# Out:
# math_pass
# P    960
# F     40
# Name: count, dtype: int64

# %%
df["read_pass"].value_counts()
# Out:
# read_pass
# P    969
# F     31
# Name: count, dtype: int64

# %%
df["write_pass"].value_counts()
# Out:
# write_pass
# P    964
# F     36
# Name: count, dtype: int64
