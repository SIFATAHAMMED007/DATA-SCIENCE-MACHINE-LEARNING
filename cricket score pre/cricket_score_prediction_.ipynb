# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/t20i_info.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed city                     venue
# 0                0  NaN  Melbourne Cricket Ground
# 1                0  NaN  Melbourne Cricket Ground
# 2                0  NaN  Melbourne Cricket Ground
# 3                0  NaN  Melbourne Cricket Ground
# 4                0  NaN  Melbourne Cricket Ground

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df.shape
# Out:
# (63888, 9)

# %%
df[df["city"].isnull()]["venue"][0].split(" ")[0]
# Out:
# 'Melbourne'

# %%
df["city"] = df["city"].fillna(df["venue"].apply(lambda x: x.split(" ")[0]))

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue
# 0                0  Melbourne  Melbourne Cricket Ground
# 1                0  Melbourne  Melbourne Cricket Ground
# 2                0  Melbourne  Melbourne Cricket Ground
# 3                0  Melbourne  Melbourne Cricket Ground
# 4                0  Melbourne  Melbourne Cricket Ground

# %%
eligible_city = df["city"].value_counts()[df["city"].value_counts() > 600].index.tolist()

# %%
eligible_city
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']

# %%
df = df[df["city"].isin(eligible_city)]

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue
# 0                0  Melbourne  Melbourne Cricket Ground
# 1                0  Melbourne  Melbourne Cricket Ground
# 2                0  Melbourne  Melbourne Cricket Ground
# 3                0  Melbourne  Melbourne Cricket Ground
# 4                0  Melbourne  Melbourne Cricket Ground

# %%
df.shape
# Out:
# (50501, 9)

# %%
df["current_score"] = df.groupby("match_id")["runs"].transform(lambda x: pd.to_numeric(x, errors='coerce').cumsum())

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue  current_score
# 0                0  Melbourne  Melbourne Cricket Ground              0
# 1                0  Melbourne  Melbourne Cricket Ground              0
# 2                0  Melbourne  Melbourne Cricket Ground              1
# 3                0  Melbourne  Melbourne Cricket Ground              3
# 4                0  Melbourne  Melbourne Cricket Ground              3

# %%
df["over"] = df["ball"].apply(lambda x : str(x).split(".")[0])
df["ball_no"] = df["ball"].apply(lambda x : str(x).split(".")[1])

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue  current_score over  \
# 0                0  Melbourne  Melbourne Cricket Ground              0    0
# 1                0  Melbourne  Melbourne Cricket Ground              0    0
# 2                0  Melbourne  Melbourne Cricket Ground              1    0
# 3                0  Melbourne  Melbourne Cricket Ground              3    0
# 4                0  Melbourne  Melbourne Cricket Ground              3    0
#
#   ball_no
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
df["ball_bowled"] = ((df["over"].astype(int)*6) + df["ball_no"].astype(int))

# %%
df.head()
# Out:
#    Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 0           0         2    Australia    Sri Lanka   0.1     0
# 1           1         2    Australia    Sri Lanka   0.2     0
# 2           2         2    Australia    Sri Lanka   0.3     1
# 3           3         2    Australia    Sri Lanka   0.4     2
# 4           4         2    Australia    Sri Lanka   0.5     0
#
#   player_dismissed       city                     venue  current_score over  \
# 0                0  Melbourne  Melbourne Cricket Ground              0    0
# 1                0  Melbourne  Melbourne Cricket Ground              0    0
# 2                0  Melbourne  Melbourne Cricket Ground              1    0
# 3                0  Melbourne  Melbourne Cricket Ground              3    0
# 4                0  Melbourne  Melbourne Cricket Ground              3    0
#
#   ball_no  ball_bowled
# 0       1            1
# 1       2            2
# 2       3            3
# 3       4            4
# 4       5            5

# %%
df["balls_left"] = 120 - df["ball_bowled"]

# %%
df["balls_left"] = df["balls_left"].apply(lambda x : 0 if x < 0 else x)

# %%
df.tail()
# Out:
#        Unnamed: 0  match_id batting_team bowling_team  ball  runs  \
# 63883         121       964    Sri Lanka    Australia  19.3     1
# 63884         122       964    Sri Lanka    Australia  19.4     0
# 63885         123       964    Sri Lanka    Australia  19.5     0
# 63886         124       964    Sri Lanka    Australia  19.6     2
# 63887         125       964    Sri Lanka    Australia  19.7     1
#
#       player_dismissed     city                venue  current_score over  \
# 63883                0  Colombo  R Premadasa Stadium            125   19
# 63884                0  Colombo  R Premadasa Stadium            125   19
# 63885      DM de Silva  Colombo  R Premadasa Stadium            125   19
# 63886                0  Colombo  R Premadasa Stadium            127   19
# 63887                0  Colombo  R Premadasa Stadium            128   19
#
#       ball_no  ball_bowled  balls_left
# 63883       3          117           3
# 63884       4          118           2
# 63885       5          119           1
# 63886       6          120           0
# 63887       7          121           0

# %%
df["player_dismissed"] = df["player_dismissed"].apply(lambda x : x if x == "0" else "1")
df["player_dismissed"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 63883    0
# 63884    0
# 63885    1
# 63886    0
# 63887    0
# Name: player_dismissed, Length: 50501, dtype: object

# %%
df["player_dismissed"] = df["player_dismissed"].astype(int)

# %%
df["player_dismissed"] = df["player_dismissed"].astype(int)  # Ensure 'player_dismissed' is numeric
df["player_dismissed"] = df.groupby("match_id")["player_dismissed"].cumsum()

# %%
df["wicket_left"] = 10 - df["player_dismissed"]

# %%
df["current_run_rate"] = (df["current_score"]*6)/df["ball_bowled"]

# %%
groups = df.groupby("match_id")
match_ids = df["match_id"].unique()
last_five = []
for id in match_ids:
    group_data = groups.get_group(id)

    group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')

    group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
    last_five.extend(group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist())
# Out:
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()
# <ipython-input-34-8b4c047b4fd1>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs"] = pd.to_numeric(group_data["runs"], errors='coerce')
# <ipython-input-34-8b4c047b4fd1>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group_data["runs_in_prev_5"] = group_data["runs"].rolling(window=30, min_periods=1).sum().values.tolist()

# %%
df["last_five"] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df, on='match_id')

# %%
final_df
# Out:
#        match_id  runs_x  Unnamed: 0 batting_team bowling_team  ball  runs_y  \
# 0             2     168           0    Australia    Sri Lanka   0.1       0
# 1             2     168           1    Australia    Sri Lanka   0.2       0
# 2             2     168           2    Australia    Sri Lanka   0.3       1
# 3             2     168           3    Australia    Sri Lanka   0.4       2
# 4             2     168           4    Australia    Sri Lanka   0.5       0
# ...         ...     ...         ...          ...          ...   ...     ...
# 50496       964     128         121    Sri Lanka    Australia  19.3       1
# 50497       964     128         122    Sri Lanka    Australia  19.4       0
# 50498       964     128         123    Sri Lanka    Australia  19.5       0
# 50499       964     128         124    Sri Lanka    Australia  19.6       2
# 50500       964     128         125    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city                     venue  current_score  \
# 0                     0  Melbourne  Melbourne Cricket Ground              0
# 1                     0  Melbourne  Melbourne Cricket Ground              0
# 2                     0  Melbourne  Melbourne Cricket Ground              1
# 3                     0  Melbourne  Melbourne Cricket Ground              3
# 4                     0  Melbourne  Melbourne Cricket Ground              3
# ...                 ...        ...                       ...            ...
# 50496                 8    Colombo       R Premadasa Stadium            125
# 50497                 8    Colombo       R Premadasa Stadium            125
# 50498                 9    Colombo       R Premadasa Stadium            125
# 50499                 9    Colombo       R Premadasa Stadium            127
# 50500                 9    Colombo       R Premadasa Stadium            128
#
#       over ball_no  ball_bowled  balls_left  wicket_left  current_run_rate  \
# 0        0       1            1         119           10          0.000000
# 1        0       2            2         118           10          0.000000
# 2        0       3            3         117           10          2.000000
# 3        0       4            4         116           10          4.500000
# 4        0       5            5         115           10          3.600000
# ...    ...     ...          ...         ...          ...               ...
# 50496   19       3          117           3            2          6.410256
# 50497   19       4          118           2            2          6.355932
# 50498   19       5          119           1            1          6.302521
# 50499   19       6          120           0            1          6.350000
# 50500   19       7          121           0            1          6.347107
#
#        last_five
# 0            0.0
# 1            0.0
# 2            1.0
# 3            3.0
# 4            3.0
# ...          ...
# 50496       32.0
# 50497       32.0
# 50498       32.0
# 50499       33.0
# 50500       32.0
#
# [50501 rows x 18 columns]

# %%
final_df.columns
# Out:
# Index(['match_id', 'runs_x', 'Unnamed: 0', 'batting_team', 'bowling_team',
#        'ball', 'runs_y', 'player_dismissed', 'city', 'venue', 'current_score',
#        'over', 'ball_no', 'ball_bowled', 'balls_left', 'wicket_left',
#        'current_run_rate', 'last_five'],
#       dtype='object')

# %%
final_df = final_df[['batting_team', 'bowling_team', 'city', 'current_score', 'balls_left', 'wicket_left',
       'current_run_rate', 'last_five', 'runs_x']]

# %%
final_df.dropna(inplace=True)
# Out:
# <ipython-input-40-3665e38311c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 50496    Sri Lanka    Australia    Colombo            125           3
# 50497    Sri Lanka    Australia    Colombo            125           2
# 50498    Sri Lanka    Australia    Colombo            125           1
# 50499    Sri Lanka    Australia    Colombo            127           0
# 50500    Sri Lanka    Australia    Colombo            128           0
#
#        wicket_left  current_run_rate  last_five  runs_x
# 0               10          0.000000        0.0     168
# 1               10          0.000000        0.0     168
# 2               10          2.000000        1.0     168
# 3               10          4.500000        3.0     168
# 4               10          3.600000        3.0     168
# ...            ...               ...        ...     ...
# 50496            2          6.410256       32.0     128
# 50497            2          6.355932       32.0     128
# 50498            1          6.302521       32.0     128
# 50499            1          6.350000       33.0     128
# 50500            1          6.347107       32.0     128
#
# [50501 rows x 9 columns]

# %%
final_df.shape
# Out:
# (50501, 9)

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.shape
# Out:
# (50501, 9)

# %%
x = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#        batting_team bowling_team             city  current_score  balls_left  \
# 40291  South Africa      England       Chittagong            129          23
# 39715   West Indies   Bangladesh           Mirpur             31          96
# 1804    New Zealand    Australia           Sydney             55          52
# 14479   West Indies  New Zealand         Auckland             43          67
# 4131       Pakistan  New Zealand  Mount Maunganui             12         112
# ...             ...          ...              ...            ...         ...
# 1014          India      England        Bangalore             33          93
# 5391      Sri Lanka        India           Mumbai             38          82
# 16369    Bangladesh    Australia        Cape Town             88          34
# 37413     Australia      England           Sydney            146          18
# 18868       England  New Zealand     Christchurch            188           3
#
#        wicket_left  current_run_rate  last_five
# 40291            7          7.979381       37.0
# 39715           10          7.750000       31.0
# 1804             6          4.852941       23.0
# 14479            7          4.867925       29.0
# 4131            10          9.000000       12.0
# ...            ...               ...        ...
# 1014             9          7.333333       33.0
# 5391             7          6.000000       30.0
# 16369            7          6.139535       28.0
# 37413            4          8.588235       42.0
# 18868            4          9.641026       64.0
#
# [40400 rows x 8 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error,accuracy_score

# %%
transformer = ColumnTransformer([
    ('transformer', OneHotEncoder(sparse_output=False, drop='first'),['batting_team','bowling_team', 'city']) # Changed 'sparse' to 'sparse_output'
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1', transformer),
    ('step2', StandardScaler()),
    ('step3', XGBRegressor(n_estimators=1000, learning_rate=0.2, max_depth=12, random_state=1))
])

# %%
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The XGBRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-3ae8b8612eb4> in <cell line: 2>()
#       1 pipe.fit(x_train, y_train)
# ----> 2 y_pred = pipe.predict(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     778         """
#     779         # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 780         with _raise_or_warn_if_not_fitted(self):
#     781             Xt = X
#     782
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     140         if typ is None:
#     141             try:
# --> 142                 next(self.gen)
#     143             except StopIteration:
#     144                 return False
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in _raise_or_warn_if_not_fitted(estimator)
#      58     # we only get here if the above didn't raise
#      59     try:
# ---> 60         check_is_fitted(estimator)
#      61     except NotFittedError:
#      62         warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1754         return
#    1755
# -> 1756     if not _is_fitted(estimator, attributes, all_or_any):
#    1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _is_fitted(estimator, attributes, all_or_any)
#    1663
#    1664     if hasattr(estimator, "__sklearn_is_fitted__"):
# -> 1665         return estimator.__sklearn_is_fitted__()
#    1666
#    1667     fitted_attrs = [
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in __sklearn_is_fitted__(self)
#    1308             # means the previous steps should also be fit. This is faster than
#    1309             # checking if every step of the pipeline is fit.
# -> 1310             check_is_fitted(last_step)
#    1311             return True
#    1312         except NotFittedError:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1749         raise TypeError("%s is not an estimator instance." % (estimator))
#    1750
# -> 1751     tags = get_tags(estimator)
#    1752
#    1753     if not tags.requires_fit and attributes is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py in get_tags(estimator)
#     403         for klass in reversed(type(estimator).mro()):
#     404             if "__sklearn_tags__" in vars(klass):
# --> 405                 sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     406                 class_order.append(klass)
#     407             elif "_more_tags" in vars(klass):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in __sklearn_tags__(self)
#     611
#     612     def __sklearn_tags__(self):
# --> 613         tags = super().__sklearn_tags__()
#     614         tags.estimator_type = "regressor"
#     615         tags.regressor_tags = RegressorTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %%
r2_score(y_test, y_pred)

# %%
mean_absolute_error(y_test, y_pred)
